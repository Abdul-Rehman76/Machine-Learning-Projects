# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# # Importing Libraries

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %% [markdown]
# # Importing Dataset

# %%
dataset=pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/ML A-Z Projects /Part 2 Regression/Simple Regression/Salary_Data.csv")
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %% [markdown]
# # Splitting dataset

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,  y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# # Training Simple Linear Regression Model on training set

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()                                               #lr stands for linear regression
lr.fit(x_train, y_train)                                                            # fit method is used to train the model
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting the test set result

# %%
y_predict = lr.predict(X=x_test)

# %% [markdown]
# # Visualising Training Set results

# %%
plt.scatter(x_train,y_train, color='red')
plt.plot(x_train,lr.predict(X=x_train),color="blue")
plt.title("Salary vs Experience (Training Set)")
plt.xlabel('Years of experience')
plt.xlabel('Salary')
plt.show()

# %% [markdown]
# # Visualising Test set results

# %%
plt.scatter(x_test,y_test, color='red')
plt.plot(x_train,lr.predict(X=x_train),color="blue")
plt.title("Salary vs Experience (Test Set)")
plt.xlabel('Years of experience')
plt.xlabel('Salary')
plt.show()

# %%
plt.scatter(x_test,y_test, color='red')
plt.plot(x_test, y_predict ,color="blue")
plt.title("Salary vs Experience (Test Set)")
plt.xlabel('Years of experience')
plt.xlabel('Salary')
plt.show()
